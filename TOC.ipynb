# %% [markdown]
# # Table of Contents
#
# If you want to obtain the latest version of a file, but keep edits you made, right-click it and rename your file by e.g. appending "_v1" to it. Close and restart your JupyterHub instance with the Toledo link. The new file should appear. You can also simply remove the file, but in that case your edits will of course be lost.
#
# Datasets and other files can be found in the *shared* folder (read-only).
#
# **Do not edit this TOC file. If you accidently did, delete it and restart your JupyterHub instance.**
#
# ### Session 1: Visualisation of Qualitative Data
# [Assignment](./Session1.ipynb)
